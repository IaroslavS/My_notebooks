# %%
import os

# %%
a = open("/home/cds-s/workspace/Patch-NetVLAD/patchnetvlad/dataset_imagenames/hpointloc_imageNames_query.txt", "r")
lines = a.readlines()
lines
# Out:
# ['17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0000.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0001.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0002.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0003.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0004.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0005.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0006.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0007.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0008.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0009.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0010.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0011.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0012.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0013.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0014.png\n',
#  '17DRP5sb8fy/images/17DRP5sb8fy_point0_query_0015.png\n',
# ...

# %%
import cv2
import numpy as np

# %%
a = cv2.imread("/media/cds-s/ExternDisk/cse_cutout_000_0_-30.png")

# %%
np.unique(a)
# Out:
# array([ 2, 22, 24, 26, 33, 56, 58], dtype=uint8)

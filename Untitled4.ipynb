# %%
data1 = open('/media/cds-s/data/Datasets/Husky-NKBVS/00_map_half_2020-03-17-14-21-57/timestamps_of_geo_poses_atlans(camera_lidar_timestamps).txt', 'r')

# %%
import numpy as np

# %%
data2 = open('/media/cds-s/data/Datasets/Husky-NKBVS/00_map_half_2020-03-17-14-21-57/RGBD_run_slam_ros/timestamps.txt','r')

# %%
lines1 = data1.readlines()
lines2 = data2.readlines()

# %%
for time in lines2:
    diff = abs( np.array(list(map(float, lines1))) - float(time))
    if min(diff) > 0.05:
        print(time)
        print(lines1[np.argmin(diff)])
# Out:
# 1584444183.400037
#
# 1584444183.329671144

# %%
len(lines1)
# Out:
# 0

# %%
lines1
# Out:
# ['1584444118.193516254\n',
#  '1584444118.293587446\n',
#  '1584444118.393537521\n',
#  '1584444118.493555546\n',
#  '1584444118.593554735\n',
#  '1584444118.693563461\n',
#  '1584444118.793599367\n',
#  '1584444118.893650770\n',
#  '1584444118.993610382\n',
#  '1584444119.093633175\n',
#  '1584444119.193616867\n',
#  '1584444119.293710709\n',
#  '1584444119.393621683\n',
#  '1584444119.493599653\n',
#  '1584444119.593627930\n',
#  '1584444119.693652391\n',
#  '1584444119.793721437\n',
#  '1584444119.893954754\n',
#  '1584444119.993725777\n',
#  '1584444120.093702316\n',
#  '1584444120.193702221\n',
#  '1584444120.293783426\n',
#  '1584444120.393722773\n',
#  '1584444120.493755579\n',
#  '1584444120.593741655\n',
#  '1584444120.693760872\n',
#  '1584444120.793858290\n',
#  '1584444120.893792152\n',
#  '1584444120.993804932\n',
#  '1584444121.093800545\n',
#  '1584444121.193812609\n',
#  '1584444121.293895483\n',
#  '1584444121.393826246\n',
#  '1584444121.493799210\n',
# ...

# %%
list(map(float, lines1))
# Out:
# []

# %%
lines2
# Out:
# ['1584444118.500048\n',
#  '1584444118.600044\n',
#  '1584444118.700040\n',
#  '1584444118.800037\n',
#  '1584444118.900046\n',
#  '1584444119.000042\n',
#  '1584444119.100038\n',
#  '1584444119.200048\n',
#  '1584444119.300045\n',
#  '1584444119.400041\n',
#  '1584444119.500037\n',
#  '1584444119.600047\n',
#  '1584444119.700042\n',
#  '1584444119.800039\n',
#  '1584444119.900049\n',
#  '1584444120.000045\n',
#  '1584444120.100041\n',
#  '1584444120.200037\n',
#  '1584444120.300047\n',
#  '1584444120.400043\n',
#  '1584444120.500039\n',
#  '1584444120.600035\n',
#  '1584444120.700045\n',
#  '1584444120.800041\n',
#  '1584444120.900037\n',
#  '1584444121.000047\n',
#  '1584444121.100044\n',
#  '1584444121.200039\n',
#  '1584444121.300035\n',
#  '1584444121.400046\n',
#  '1584444121.500042\n',
#  '1584444121.600038\n',
#  '1584444121.700048\n',
#  '1584444121.800044\n',
#  '1584444122.000036\n',
#  '1584444122.100046\n',
#  '1584444122.200042\n',
#  '1584444122.300038\n',
# ...

# %%
a = lines2

# %%
np.array(list(map(float, lines2)))
# Out:
# array([1.58444412e+09, 1.58444412e+09, 1.58444412e+09, ...,
#        1.58444425e+09, 1.58444425e+09, 1.58444425e+09])
